# %%
from pathlib import Path
import pickle
import pandas as pd

# %%
val = Path('/home/wong/Desktop/FYP/Argoverse_1/crat-pred/dataset/argoverse/val_pre.pkl')

# %%
with open(val, 'rb') as f:
    data = pickle.load(f)

# %%
data

# %%
data[1]
# Out:
# {'argo_id': 10,
#  'city': 'PIT',
#  'past_trajs': array([[[-2.20467300e+01, -1.88597679e-01,  1.00000000e+00],
#          [-2.00810966e+01, -2.54516602e-01,  1.00000000e+00],
#          [-1.89607697e+01, -2.59755135e-01,  1.00000000e+00],
#          [-1.80451488e+01, -2.84948349e-01,  1.00000000e+00],
#          [-1.72236710e+01, -3.88748169e-01,  1.00000000e+00],
#          [-1.57202425e+01, -3.40099812e-01,  1.00000000e+00],
#          [-1.46822853e+01, -2.54361153e-01,  1.00000000e+00],
#          [-1.36857681e+01, -2.14276314e-01,  1.00000000e+00],
#          [-1.24573612e+01, -2.45393753e-01,  1.00000000e+00],
#          [-1.02265673e+01, -1.18210316e-01,  1.00000000e+00],
#          [-9.35191917e+00, -1.23932362e-01,  1.00000000e+00],
#          [-8.50018883e+00, -1.15556717e-02,  1.00000000e+00],
#          [-6.90135479e+00, -5.76946735e-02,  1.00000000e+00],
#          [-6.03717613e+00, -3.75502110e-02,  1.00000000e+00],
# ...
